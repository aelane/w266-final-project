# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
PATH_SaO = r'/Users/annielane/Documents/MIDS/W266/w266-final-project/data/processed/amazon/Sports_Outdoors/product_features_txt'
PATH_OS = r'/Users/annielane/Documents/MIDS/W266/w266-final-project/data/processed/amazon/Office_Products'

# %% [markdown]
# # Process Office Supplies

# %%
list_OS = os.listdir(PATH_SaO)
split_OS = [file.split('_') for file in list_OS]
split_OS[0]
df_OS = pd.DataFrame(split_OS, columns = ['asin', 'feature'])
df_OS['feature'] = df_OS['feature'].str.strip('.txt')
df_OS.head()
# Out:
#          asin feature
# 0  B002CBWQ0C  sheath
# 1  B001817CL0     cup
# 2  B00437VTJ2   water
# 3  B007OX9X9K  bottle
# 4  B001EJMS6K    door

# %%
df_OS['feature'].value_counts()
# Out:
# knife        571
# produc       196
# bag          184
# scope        167
# blade        148
# bike         146
# price        113
# holster      111
# ligh         107
# water        100
# watch         96
# case          93
# ool           89
# gun           85
# quality       83
# bottle        69
# hing          69
# en            64
# sheath        58
# sigh          55
# knives        54
# gloves        51
# chain         47
# size          46
# bel           44
# ki            43
# grip          42
# ime           42
# pack          41
# pump          39
#             ...
# visor          1
# compasses      1
# soccer         1
# ear            1
# pistols        1
# ackle          1
# home           1
# pool           1
# mats           1
# feature        1
# polymer        1
# attention      1
# candles        1
# clubs          1
# switch         1
# strands        1
# finger         1
# scen           1
# peppermin      1
# reloader       1
# deal           1
# ...

# %%
df_OS['asin'].value_counts().describe([0.25, 0.5, 0.75, 0.90])
# Out:
# count    3658.000000
# mean        1.826408
# std         2.625300
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# 90%         3.000000
# max        66.000000
# Name: asin, dtype: float64

# %%
df_OS['asin'].describe()
# Out:
# count           6681
# unique          3658
# top       B001T7QJ9O
# freq              66
# Name: asin, dtype: object

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
df_OS['asin'].value_counts().hist(bins = 22)
# Out:
# <img src="data:image/png;base64,..." width="640">
